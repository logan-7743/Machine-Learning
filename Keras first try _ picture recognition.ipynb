# %%
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
batch_size = 128
num_classes = 10
epochs = 20

# %%
(x_train,y_train), (x_test,y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000,784)
x_train = x_train.astype("float32")
x_test = x_test.astype("float32")
x_train /= 255
x_test /=255

# %%
y_train = to_categorical(y_train,num_classes)
y_test  = to_categorical(y_test,num_classes)

# %%
model = Sequential()
model.add(Dense(512, activation = "relu",input_shape=(784,)))
model.add(Dropout(.2))
model.add(Dense(512,activation = "relu"))
model.add(Dropout(.2))
model.add(Dense(num_classes,activation="softmax"))

model.summary()

# %%
model.compile(loss="categorical_crossentropy",
              optimizer = "sgd",
              metrics=["accuracy"]
              )

# %%
model.summary()

# %%
model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print(score[0])
print(score[1])
# Out:
# Epoch 1/20
# 469/469 [==============================] - 6s 12ms/step - loss: 1.2271 - accuracy: 0.6790 - val_loss: 0.5431 - val_accuracy: 0.8665
# Epoch 2/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.5320 - accuracy: 0.8497 - val_loss: 0.3771 - val_accuracy: 0.8993
# Epoch 3/20
# 469/469 [==============================] - 5s 12ms/step - loss: 0.4240 - accuracy: 0.8775 - val_loss: 0.3239 - val_accuracy: 0.9095
# Epoch 4/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3738 - accuracy: 0.8919 - val_loss: 0.2927 - val_accuracy: 0.9179
# Epoch 5/20
# 469/469 [==============================] - 5s 12ms/step - loss: 0.3413 - accuracy: 0.9010 - val_loss: 0.2707 - val_accuracy: 0.9240
# Epoch 6/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3169 - accuracy: 0.9081 - val_loss: 0.2536 - val_accuracy: 0.9291
# Epoch 7/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2974 - accuracy: 0.9136 - val_loss: 0.2404 - val_accuracy: 0.9324
# Epoch 8/20
# 469/469 [==============================] - 5s 12ms/step - loss: 0.2783 - accuracy: 0.9189 - val_loss: 0.2274 - val_accuracy: 0.9347
# Epoch 9/20
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2672 - accuracy: 0.9227 - val_loss: 0.2159 - val_accuracy: 0.9379
# Epoch 10/20
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2534 - accuracy: 0.9263 - val_loss: 0.2059 - val_accuracy: 0.9407
# Epoch 11/20
# 469/469 [==============================] - 5s 12ms/step - loss: 0.2416 - accuracy: 0.9304 - val_loss: 0.1983 - val_accuracy: 0.9429
# Epoch 12/20
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2312 - accuracy: 0.9331 - val_loss: 0.1900 - val_accuracy: 0.9447
# Epoch 13/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2223 - accuracy: 0.9352 - val_loss: 0.1834 - val_accuracy: 0.9462
# Epoch 14/20
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2130 - accuracy: 0.9386 - val_loss: 0.1762 - val_accuracy: 0.9483
# Epoch 15/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2058 - accuracy: 0.9399 - val_loss: 0.1693 - val_accuracy: 0.9495
# Epoch 16/20
# 469/469 [==============================] - 5s 12ms/step - loss: 0.1974 - accuracy: 0.9432 - val_loss: 0.1642 - val_accuracy: 0.9509
# Epoch 17/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1911 - accuracy: 0.9439 - val_loss: 0.1589 - val_accuracy: 0.9531
# Epoch 18/20
# 469/469 [==============================] - 5s 12ms/step - loss: 0.1854 - accuracy: 0.9449 - val_loss: 0.1536 - val_accuracy: 0.9540
# Epoch 19/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1800 - accuracy: 0.9472 - val_loss: 0.1494 - val_accuracy: 0.9553
# Epoch 20/20
# 469/469 [==============================] - 5s 12ms/step - loss: 0.1730 - accuracy: 0.9501 - val_loss: 0.1469 - val_accuracy: 0.9560
# 0.1468888521194458
# 0.9559999704360962
